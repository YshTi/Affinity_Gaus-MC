# %%
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import xlsxwriter
import pylab as py

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times"
})

# %% [markdown]
# # MC + Gaus Rowan data

# %%
Data_MC = pd.read_excel('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/CLAS12_1400affinity_Rowan_data_0.3.xlsx')
Data_MC.keys()
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'x', 'z', 'Q2', 'pT', 'target', 'hadron',
#        'partonicaff', 'currentaff', 'tmdaff', 'tmdnpaff', 'collinearaff',
#        'collinearloworderaff', 'collinearhighorderaff', 'matchaff', 'softaff',
#        'targetaff', 'unclassifiedaff', 'R0', 'R1', 'R1p', 'R2', 'R3', 'R4',
#        'R5', 'qT', 'xN', 'zN', 'yp', 'yh', 'yhtarget', 'yi', 'yf'],
#       dtype='object')

# %% [markdown]
# ### Only Region indicators from MC (1 bin)

# %%
MC = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/R_values_Rowan.csv')
MC.keys()
# Out:
# Index(['Unnamed: 0', 'R0', 'R1', 'R2', 'R3'], dtype='object')

# %%
fig, axs = plt.subplots(2, 2)
fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values (Rowan data)')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(Data_MC['R0'], bins = edges1, label=['$R_0$ MC'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 0].hist(MC['R0'], bins = edges1, label=['$R_0$ MC (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 0].set_title("$R_0$", fontsize=16)
axs[0, 0].set_xlabel('$R_0$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(Data_MC['R1'], bins = edges3, label=['$R_1$ MC'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 1].hist(MC['R1'], bins = edges3, label=['$R_1$ MC (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 1].set_title("$R_1$", fontsize=16)
axs[0, 1].set_xlabel('$R_1$ values')
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 4, 20)

axs[1, 0].hist(Data_MC['R2'], bins = edges2, label=['$R_2$ MC'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 0].hist(MC['R2'], bins = edges2, label=['$R_2$ MC (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 0].set_title("$R_2$", fontsize=16)
axs[1, 0].set_xlabel('$R_2$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 4, 20)

axs[1, 1].hist(Data_MC['R3'], bins = edges4, label=['$R_3$ MC'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 1].hist(MC['R3'], bins = edges4, label=['$R_3$ MC (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 1].set_title("$R_3$", fontsize=16)
axs[1, 1].set_xlabel('$R_3$ values')
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %% [markdown]
# # Only MC Rowan data

# %%
Data_MC_only = pd.read_excel('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/CLAS12_1400affinity_MC_params_0.3.xlsx')
Data_MC_only.keys()
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'x', 'z', 'Q2', 'pT', 'target', 'hadron',
#        'partonicaff', 'currentaff', 'tmdaff', 'tmdnpaff', 'collinearaff',
#        'collinearloworderaff', 'collinearhighorderaff', 'matchaff', 'softaff',
#        'targetaff', 'unclassifiedaff', 'R0', 'R1', 'R1p', 'R2', 'R3', 'R4',
#        'R5', 'qT', 'xN', 'zN', 'yp', 'yh', 'yhtarget', 'yi', 'yf'],
#       dtype='object')

# %% [markdown]
# ### Only Region indicators from Rowan data (1 bin)

# %%
Harut = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/R_values_Rowan_all_par.csv')
Harut.keys()
# Out:
# Index(['Unnamed: 0', 'R0', 'R1', 'R2', 'R3'], dtype='object')

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values (Harut data)')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(Data_MC_only['R0'], bins = edges1, label=['$R_0$ MC+Gaus'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 0].hist(Harut['R0'], bins = edges1, label=['$R_0$ MC+Gaus (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 0].set_title("$R_0$", fontsize=16)
axs[0, 0].set_xlabel('$R_0$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(Data_MC_only['R1'], bins = edges3, label=['$R_1$ MC+Gaus'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 1].hist(Harut['R1'], bins = edges3, label=['$R_1$ MC+Gaus (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[0, 1].set_title("$R_1$", fontsize=16)
axs[0, 1].set_xlabel('$R_1$ values')
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 4, 20)

axs[1, 0].hist(Data_MC_only['R2'], bins = edges2, label=['$R_2$ MC+Gaus'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 0].hist(Harut['R2'], bins = edges2, label=['$R_2$ MC+Gaus (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 0].set_title("$R_2$", fontsize=16)
axs[1, 0].set_xlabel('$R_2$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 4, 20)

axs[1, 1].hist(Data_MC_only['R3'], bins = edges4, label=['$R_3$ MC+Gaus'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 1].hist(Harut['R3'], bins = edges4, label=['$R_3$ MC+Gaus (1 bin)'], linewidth=2, histtype='step', stacked=True, density=False)
axs[1, 1].set_title("$R_3$", fontsize=16)
axs[1, 1].set_xlabel('$R_3$ values')
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %% [markdown]
# # _________________________________________________________________________

# %% [markdown]
# # Region indicators Rowan data full MC and MC+Gaus

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values (Gaussian + MC) JLab12')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(Data_MC_only['R0'], alpha = 0.5, bins = edges1, label='$R_0$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 0].hist(Data_MC['R0'], alpha = 0.5, bins = edges1, label=['$R_0$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 0].set_title("$R_0$", fontsize=16)
axs[0, 0].set_xlabel('$R_0$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 2.2, step=0.2))
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(Data_MC_only['R1'], alpha = 0.5, bins = edges3, label='$R_1$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 1].hist(Data_MC['R1'], alpha = 0.5, bins = edges3, label=['$R_1$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 1].set_title("$R_1$", fontsize=16)
axs[0, 1].set_xlabel('$R_1$ values')
axs[0, 1].set_xticks(np.arange(0, 2.2, step=0.5))
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 4, 20)

axs[1, 0].hist(Data_MC_only['R2'], alpha = 0.5, bins = edges2, label='$R_2$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 0].hist(Data_MC['R2'], alpha = 0.5, bins = edges2, label=['$R_2$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 0].set_title("$R_2$", fontsize=16)
axs[1, 0].set_xlabel('$R_2$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 4, 20)

axs[1, 1].hist(Data_MC_only['R3'], alpha = 0.5, bins = edges4, label='$R_3$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 1].hist(Data_MC['R3'], alpha = 0.5, bins = edges4, label=['$R_3$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 1].set_title("$R_3$", fontsize=16)
axs[1, 1].set_xlabel('$R_3$ values')
axs[1, 1].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('Kinematical values (Gaussian + MC) JLab12')

edges1 = np.linspace(0, 0.8, 20)

axs[0, 0].hist(Data_Harut['x'], alpha = 0.5, bins = edges1, label='$x$ Harut data', linewidth=2, histtype='stepfilled', density=False)
axs[0, 0].hist(Data_MC['x'], alpha = 0.5, bins = edges1, label=['$x$ Rowan data'], linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 0].set_title("$x$", fontsize=16)
axs[0, 0].set_xlabel('$x$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 1.2, step=0.2))
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 1, 20)

axs[0, 1].hist(Data_Harut['z'], alpha = 0.5, bins = edges3, label='$z$ Harut data', linewidth=2, histtype='stepfilled', density=False)
axs[0, 1].hist(Data_MC['z'], alpha = 0.5, bins = edges3, label=['$z$ Rowan data'], linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 1].set_title("$z$", fontsize=16)
axs[0, 1].set_xlabel('$z$ values')
axs[0, 1].set_xticks(np.arange(0, 1.2, step=0.5))
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 2.5, 20)

axs[1, 0].hist(Data_Harut['pT'], alpha = 0.5, bins = edges2, label='$pT$ Harut data', linewidth=2, histtype='stepfilled', density=False)
axs[1, 0].hist(Data_MC['pT'], alpha = 0.5, bins = edges2, label=['$pT$ Rowan data'], linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 0].set_title("$pT$", fontsize=16)
axs[1, 0].set_xlabel('$pT$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 2.6, step=0.5))
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 15, 20)

axs[1, 1].hist(Data_Harut['Q2'], alpha = 0.5, bins = edges4, label='$Q^2$ Harut data', linewidth=2, histtype='stepfilled', density=False)
axs[1, 1].hist(Data_MC['Q2'], alpha = 0.5, bins = edges4, label=['$Q^2$ Rowan data'], linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 1].set_title("$Q^2$", fontsize=16)
axs[1, 1].set_xlabel('$Q^2$ values')
# axs[1, 1].set_xticks(np.arange(0, 15, step=0.5))
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %% [markdown]
# # _________________________________________________________________________

# %% [markdown]
# # Kinematical variables

# %%
pd.options.mode.chained_assignment = None  # default='warn'
from tools import save, load, lprint, checkdir

from plottools import above, below, left, right, plotJLab12, custom_label, color_plot, color_plot_hull

#--matplotlib
import matplotlib
matplotlib.use('PS')
matplotlib.rc('text',usetex=True)
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.lines import Line2D
plt.rcParams["font.family"] = "Times New Roman"

import matplotlib.gridspec as gridspec
# %matplotlib inline

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
def plotkin():
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/CLAS12_1400affinity_Rowan_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert_lab = "Q2" 
    hor_lab = "x"
    alpha=0.8

    # Rowan
    vert = data[vert_lab].values
    hor = data[hor_lab].values


    colors = data["tmdaff"]


    fig, ax = plt.subplots()
    ax.tick_params(axis='both', which='minor', labelsize=30, direction='in')
    #ax.tick_params(axis='both', which='major', labelsize=20, direction='in')
    #ax.tick_params(axis='both', which='both', labelsize=20, direction='in')
    #ax.tick_params(axis=‘both’, which=‘both’, labelsize=20, direction=‘in’, length=6)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)



    ax.set_ylabel(custom_label(vert_lab),
                            size=20)
    ax.set_xlabel(custom_label(hor_lab),
                            size=20)

    

    plot = ax.scatter(hor, vert, c="darkorange", alpha=0.8, s=5.5, zorder=7)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'darkorange', alpha=alpha,zorder=6) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'darkorange',edgecolor='darkorange', alpha=0.3, label=r'\boldmath{$\rm Rowan \, data$}',zorder=5)


    # Harut
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/jlab12affinity_Harut_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert = data[vert_lab].values
    hor = data[hor_lab].values

    colors = data["tmdaff"]


    plot = ax.scatter(hor, vert, c="cornflowerblue", alpha=0.8, s=5.5, zorder=12)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'cornflowerblue', alpha=alpha,zorder=11) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'cornflowerblue', edgecolor='cornflowerblue', alpha=0.3, label=r'\boldmath{$\rm Harut \, data$}',zorder=10)

    
    
    
    fig.tight_layout()

    ax.legend(prop={"size":16},frameon=0,handletextpad=0.3)

#     ax.set_yscale("log")
    ax.set_ylim([0.0, 12])
#     ax.set_xscale("log")
    ax.set_xlim([0.0, 0.7])

    plt.savefig("./Figs/experiments_kinematics.pdf", bbox_inches='tight')
    plt.show()

plotkin()

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
def plotkin():
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/CLAS12_1400affinity_Rowan_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert_lab = "pT" 
    hor_lab = "z"
    alpha=0.8

    # Rowan
    vert = data[vert_lab].values
    hor = data[hor_lab].values


    colors = data["tmdaff"]


    fig, ax = plt.subplots()
    ax.tick_params(axis='both', which='minor', labelsize=30, direction='in')
    #ax.tick_params(axis='both', which='major', labelsize=20, direction='in')
    #ax.tick_params(axis='both', which='both', labelsize=20, direction='in')
    #ax.tick_params(axis=‘both’, which=‘both’, labelsize=20, direction=‘in’, length=6)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)



    ax.set_ylabel(custom_label(vert_lab),
                            size=20)
    ax.set_xlabel(custom_label(hor_lab),
                            size=20)

    

    plot = ax.scatter(hor, vert, c="darkorange", alpha=0.8, s=5.5, zorder=7)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'darkorange', alpha=alpha,zorder=6) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'darkorange',edgecolor='darkorange', alpha=0.3, label=r'\boldmath{$\rm Rowan \, data$}',zorder=5)


    # Harut
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/jlab12affinity_Harut_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert = data[vert_lab].values
    hor = data[hor_lab].values

    colors = data["tmdaff"]


    plot = ax.scatter(hor, vert, c="cornflowerblue", alpha=0.8, s=5.5, zorder=12)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'cornflowerblue', alpha=alpha,zorder=11) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'cornflowerblue', edgecolor='cornflowerblue', alpha=0.3, label=r'\boldmath{$\rm Harut \, data$}',zorder=10)

    
    
    
    fig.tight_layout()

    ax.legend(prop={"size":16},frameon=0,handletextpad=0.3)

#     ax.set_yscale("log")
    ax.set_ylim([0.0, 4])
#     ax.set_xscale("log")
    ax.set_xlim([0.0, 1])

    plt.savefig("./Figs/experiments_pToverZ.pdf", bbox_inches='tight')
    plt.show()

plotkin()

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
def plotkin():
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/CLAS12_1400affinity_Rowan_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert_lab = "qT" 
    hor_lab = "z"
    alpha=0.8

    # Rowan
    vert = data[vert_lab].values
    hor = data[hor_lab].values


    colors = data["tmdaff"]


    fig, ax = plt.subplots()
    ax.tick_params(axis='both', which='minor', labelsize=30, direction='in')
    #ax.tick_params(axis='both', which='major', labelsize=20, direction='in')
    #ax.tick_params(axis='both', which='both', labelsize=20, direction='in')
    #ax.tick_params(axis=‘both’, which=‘both’, labelsize=20, direction=‘in’, length=6)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)



    ax.set_ylabel(custom_label(vert_lab),
                            size=20)
    ax.set_xlabel(custom_label(hor_lab),
                            size=20)

    

    plot = ax.scatter(hor, vert, c="darkorange", alpha=0.8, s=5.5, zorder=7)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'darkorange', alpha=alpha,zorder=6) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'darkorange',edgecolor='darkorange', alpha=0.3, label=r'\boldmath{$\rm Rowan \, data$}',zorder=5)


    # Harut
    fname = '/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/jlab12affinity_Harut_data_0.3.xlsx'
    data=pd.read_excel(fname)


    vert = data[vert_lab].values
    hor = data[hor_lab].values

    colors = data["tmdaff"]


    plot = ax.scatter(hor, vert, c="cornflowerblue", alpha=0.8, s=5.5, zorder=12)

    points = np.ndarray(shape=(len(vert),2), dtype=float)
    for i in range(len(vert)):
            points[i,0] = hor[i]
            points[i,1] = vert[i]

    hull = ConvexHull(points)

    for simplex in hull.simplices:
            ax.plot(points[simplex, 0], points[simplex, 1], 'cornflowerblue', alpha=alpha,zorder=11) 
    ax.fill(points[hull.vertices,0], points[hull.vertices,1], 'cornflowerblue', edgecolor='cornflowerblue', alpha=0.3, label=r'\boldmath{$\rm Harut \, data$}',zorder=10)

    
    
    
    fig.tight_layout()

    ax.legend(prop={"size":16},frameon=0,handletextpad=0.3)

#     ax.set_yscale("log")
    ax.set_ylim([0.0, 10])
#     ax.set_xscale("log")
    ax.set_xlim([0.0, 1])

    plt.savefig("./Figs/experiments_pToverZ.pdf", bbox_inches='tight')
    plt.show()

plotkin()

# %% [markdown]
# # _________________________________________________________________________

# %% [markdown]
# # Non-perturbative values

# %%
Rowan = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/Non_pert_Parameters_MC_1k_Rowan_no_xi_zeta.csv')
Rowan.keys()
# Out:
# Index(['Unnamed: 0', 'xi', 'zeta', 'delta_k_t', 'M_kf', 'k_iT', 'M_ki', 'phi',
#        'phi_i', 'phi_ki'],
#       dtype='object')

# %%
Gaus = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/Gaus_MC_mixed.csv')
Gaus.keys()
# Out:
# Index(['Unnamed: 0', 'xi', 'zeta', 'delta_k_t', 'M_kf', 'k_iT', 'M_ki', 'phi',
#        'phi_i', 'phi_ki'],
#       dtype='object')

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values JLab12')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(Rowan['k_iT'], alpha = 0.5, bins = edges1, label='$k_{it}$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 0].hist(Gaus['k_iT'], alpha = 0.5, bins = edges1, label=['$k_{it}$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 0].set_title("$k_{it}$", fontsize=16)
axs[0, 0].set_xlabel('$k_{it}$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 2.2, step=0.2))
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(Rowan['M_ki'], alpha = 0.5, bins = edges3, label='$M_{ki}$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 1].hist(Gaus['M_ki'], alpha = 0.5, bins = edges3, label=['$M_{ki}$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 1].set_title("$M_{ki}$", fontsize=16)
axs[0, 1].set_xlabel('$M_{ki}$ values')
axs[0, 1].set_xticks(np.arange(0, 2.2, step=0.5))
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 3, 20)

axs[1, 0].hist(Rowan['delta_k_t'], alpha = 0.5, bins = edges2, label='$\delta k_t$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 0].hist(Gaus['delta_k_t'], alpha = 0.5, bins = edges2, label=['$\delta k_t$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 0].set_title("$\delta k_t$", fontsize=16)
axs[1, 0].set_xlabel('$\delta k_t$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 3.1, step=0.5))
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 2, 20)

axs[1, 1].hist(Rowan['M_kf'], alpha = 0.5, bins = edges4, label='$M_{kf}$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 1].hist(Gaus['M_kf'], alpha = 0.5, bins = edges4, label=['$M_{kf}$ MC + Gaus'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 1].set_title("$M_{kf}$", fontsize=16)
axs[1, 1].set_xlabel('$M_{kf}$ values')
axs[1, 1].set_xticks(np.arange(0, 2.1, step=0.5))
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
# fig.subplots_adjust(left=0.8, wspace=2)
fig.set_size_inches(18.5, 5.5)

plt.rcParams['text.usetex'] = True
fig.suptitle('Angles JLab12', fontsize=30)

a = Rowan['phi']                   # A uniform distribution
b = Gaus['phi']          # A normal distribution 
edges7 = np.histogram(np.hstack((a,b)), bins=100)[1] # Get the bin edges

ax1.hist(Gaus['phi'], alpha = 0.5, bins = edges7, label='$\phi$ Gaussian', linewidth=2, histtype='stepfilled', stacked=True, density=False)
ax1.hist(Rowan['phi'], alpha = 0.5, bins = edges7, label=['$\phi$ MC'], linewidth=2, histtype='stepfilled', density=False)
ax1.set_title("$\phi$", fontsize=24)
ax1.set_xlabel('$\phi$ values', fontsize=20)
ax1.set_ylabel('Number of counts', fontsize=20)
# axs[1, 0].set_xticks(np.arange(0, 4.1, step=0.5))
ax1.legend(fontsize=14)

a = Rowan['phi_i']                   # A uniform distribution
b = Gaus['phi_i']          # A normal distribution 
edges8 = np.histogram(np.hstack((a,b)), bins=100)[1] # Get the bin edges

ax2.hist(Gaus['phi_i'], alpha = 0.5, bins = edges8, label='$\phi_i$ Gaussian', linewidth=2, histtype='stepfilled', stacked=True, density=False)
ax2.hist(Rowan['phi_i'], alpha = 0.5, bins = edges8, label=['$\phi_i$ MC'], linewidth=2, histtype='stepfilled', density=False)
ax2.set_title("$\phi_i$", fontsize=24)
ax2.set_xlabel('$\phi_i$ values', fontsize=20)
# axs[1, 1].set_xticks(np.arange(0, 4.1, step=0.5))
ax2.legend(fontsize=14)

a = Rowan['phi_ki']                   # A uniform distribution
b = Gaus['phi_ki']          # A normal distribution 
edges9 = np.histogram(np.hstack((a,b)), bins=100)[1] # Get the bin edges

ax3.hist(Gaus['phi_ki'], alpha = 0.5, bins = edges9, label='$\phi_{k_i}$ Gaussian', linewidth=2, histtype='stepfilled', density=False)
ax3.hist(Rowan['phi_ki'], alpha = 0.5, bins = edges9, label=['$\phi_{k_i}$ MC'], linewidth=2, histtype='stepfilled', density=False)
ax3.set_title("$\phi_{k_i}$", fontsize=24)
ax3.set_xlabel('$\phi_{k_i}$ values', fontsize=20)
ax3.legend(fontsize=14)


fig.tight_layout()

# %% [markdown]
# # Similar bin

# %%
Rowan_bin = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/R_values_Rowan.csv')
Rowan_bin.keys()
# Out:
# Index(['Unnamed: 0', 'R0', 'R1', 'R2', 'R3'], dtype='object')

# %%
MCgen_bin = pd.read_csv('/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/R_values_Rowan_all_par.csv')
MCgen_bin.keys()
# Out:
# Index(['Unnamed: 0', 'R0', 'R1', 'R2', 'R3'], dtype='object')

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values (Gaussian + MC) JLab12')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(MCgen_bin['R0'], alpha = 0.5, bins = edges1, label='$R_0$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 0].hist(Rowan_bin['R0'], alpha = 0.5, bins = edges1, label=['$R_0$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 0].set_title("$R_0$", fontsize=16)
axs[0, 0].set_xlabel('$R_0$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 2.2, step=0.2))
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(MCgen_bin['R1'], alpha = 0.5, bins = edges3, label='$R_1$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 1].hist(Rowan_bin['R1'], alpha = 0.5, bins = edges3, label=['$R_1$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 1].set_title("$R_1$", fontsize=16)
axs[0, 1].set_xlabel('$R_1$ values')
axs[0, 1].set_xticks(np.arange(0, 2.2, step=0.5))
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 4, 20)

axs[1, 0].hist(MCgen_bin['R2'], alpha = 0.5, bins = edges2, label='$R_2$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 0].hist(Rowan_bin['R2'], alpha = 0.5, bins = edges2, label=['$R_2$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 0].set_title("$R_2$", fontsize=16)
axs[1, 0].set_xlabel('$R_2$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 4, 20)

axs[1, 1].hist(MCgen_bin['R3'], alpha = 0.5, bins = edges4, label='$R_3$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 1].hist(Rowan_bin['R3'], alpha = 0.5, bins = edges4, label=['$R_3$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 1].set_title("$R_3$", fontsize=16)
axs[1, 1].set_xlabel('$R_3$ values')
axs[1, 1].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 1].legend(fontsize=8)

fig.tight_layout()

# %%
R_bin = pd.read_excel("/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/Rowan_similar_binaffinity_Rowan_0.3.xlsx")
R_bin.keys()
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'x', 'z', 'pT', 'Q2', 'hadron', 'target',
#        'partonicaff', 'currentaff', 'tmdaff', 'tmdnpaff', 'collinearaff',
#        'collinearloworderaff', 'collinearhighorderaff', 'matchaff', 'softaff',
#        'targetaff', 'unclassifiedaff', 'R0', 'R1', 'R1p', 'R2', 'R3', 'R4',
#        'R5', 'qT', 'xN', 'zN', 'yp', 'yh', 'yhtarget', 'yi', 'yf'],
#       dtype='object')

# %%
R_bin
# Out:
#    Unnamed: 0.1  Unnamed: 0         x       z        pT        Q2 hadron  \
# 0             0           1  0.530334  0.2459  0.393172  7.952964    pi+
#
#    target  partonicaff  currentaff  ...        R4        R5        qT  \
# 0  proton        0.746       0.605  ...  0.156484  1.854803  1.632525
#
#          xN        zN        yp        yh  yhtarget        yi        yf
# 0  0.514757  0.236143  1.763859 -0.503411  5.099763  1.348282 -0.311013
#
# [1 rows x 34 columns]

# %%
MC_bin = pd.read_excel("/Users/tetiana/Documents/Affinity/Clas12_and_Jlab12/data/Rowan_similar_binaffinity_MC_params_0.3.xlsx")
MC_bin.keys()
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'x', 'z', 'pT', 'Q2', 'hadron', 'target',
#        'partonicaff', 'currentaff', 'tmdaff', 'tmdnpaff', 'collinearaff',
#        'collinearloworderaff', 'collinearhighorderaff', 'matchaff', 'softaff',
#        'targetaff', 'unclassifiedaff', 'R0', 'R1', 'R1p', 'R2', 'R3', 'R4',
#        'R5', 'qT', 'xN', 'zN', 'yp', 'yh', 'yhtarget', 'yi', 'yf'],
#       dtype='object')

# %%
MC_bin
# Out:
#    Unnamed: 0.1  Unnamed: 0         x       z        pT        Q2 hadron  \
# 0             0           1  0.530334  0.2459  0.393172  7.952964    pi+
#
#    target  partonicaff  currentaff  ...        R4        R5        qT  \
# 0  proton        0.751       0.375  ...  0.499534  0.694079  1.632525
#
#          xN        zN        yp        yh  yhtarget        yi        yf
# 0  0.514757  0.236143  1.763859 -0.503411  5.099763  0.415642 -1.287041
#
# [1 rows x 34 columns]

# %%
fig, axs = plt.subplots(2, 2)
# fig.subplots_adjust(left=0.6, wspace=2)

plt.rcParams['text.usetex'] = True
fig.suptitle('$R_i$ values (Gaussian + MC) JLab12')

edges1 = np.linspace(0, 2, 20)

axs[0, 0].hist(MC_bin['R0'], alpha = 0.5, bins = edges1, label='$R_0$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 0].hist(R_bin['R0'], alpha = 0.5, bins = edges1, label=['$R_0$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 0].set_title("$R_0$", fontsize=16)
axs[0, 0].set_xlabel('$R_0$ values')
axs[0, 0].set_ylabel('Number of counts', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 2.2, step=0.2))
axs[0, 0].legend(fontsize=8)

edges3 = np.linspace(0, 2, 20)

axs[0, 1].hist(MC_bin['R1'], alpha = 0.5, bins = edges3, label='$R_1$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[0, 1].hist(R_bin['R1'], alpha = 0.5, bins = edges3, label=['$R_1$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[0, 1].set_title("$R_1$", fontsize=16)
axs[0, 1].set_xlabel('$R_1$ values')
axs[0, 1].set_xticks(np.arange(0, 2.2, step=0.5))
axs[0, 1].legend(fontsize=8)

edges2 = np.linspace(0, 4, 20)

axs[1, 0].hist(MC_bin['R2'], alpha = 0.5, bins = edges2, label='$R_2$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 0].hist(R_bin['R2'], alpha = 0.5, bins = edges2, label=['$R_2$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 0].set_title("$R_2$", fontsize=16)
axs[1, 0].set_xlabel('$R_2$ values')
axs[1, 0].set_ylabel('Number of counts', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 0].legend(fontsize=8)

edges4 = np.linspace(0, 4, 20)

axs[1, 1].hist(MC_bin['R3'], alpha = 0.5, bins = edges4, label='$R_3$ Only MC', color='blue', linewidth=2, histtype='stepfilled', density=False)
axs[1, 1].hist(R_bin['R3'], alpha = 0.5, bins = edges4, label=['$R_3$ Gaus+MC'], color='darkorange', linewidth=2, histtype='stepfilled', stacked=True, density=False)
axs[1, 1].set_title("$R_3$", fontsize=16)
axs[1, 1].set_xlabel('$R_3$ values')
axs[1, 1].set_xticks(np.arange(0, 4.1, step=0.5))
axs[1, 1].legend(fontsize=8)

fig.tight_layout()
